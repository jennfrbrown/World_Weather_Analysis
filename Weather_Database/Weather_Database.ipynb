# %%
#Import the dependencies
import pandas as pd
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high =90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities.
cities = []
#Identify the nearest city for each latitude and longitude combinaation.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
 #Print the city count to confirm suffucient count.
len(cities)
# Out:
# 754

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "% Humidity": city_humidity,
                          "% Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | fortuna
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | pala
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | fort nelson
# Processing Record 9 of Set 1 | gornoye loo
# Processing Record 10 of Set 1 | tondela
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 1 | tukrah
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | falun
# Processing Record 18 of Set 1 | saint george
# Processing Record 19 of Set 1 | klaksvik
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | torbay
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | slavgorodskoye
# Processing Record 24 of Set 1 | teguise
# Processing Record 25 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | pisco
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | nabire
# Processing Record 31 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | cachoeirinha
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | mareeba
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | shenkursk
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | viseu
# Processing Record 41 of Set 1 | luderitz
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | rottingdean
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | erzin
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | bethel
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | achinsk
# Processing Record 2 of Set 2 | ikalamavony
# Processing Record 3 of Set 2 | chokurdakh
# Processing Record 4 of Set 2 | san fernando
# Processing Record 5 of Set 2 | concarneau
# Processing Record 6 of Set 2 | kenai
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | sabzevar
# Processing Record 9 of Set 2 | skjervoy
# Processing Record 10 of Set 2 | dunedin
# Processing Record 11 of Set 2 | sitka
# Processing Record 12 of Set 2 | dwarka
# Processing Record 13 of Set 2 | nuuk
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | eldorado
# Processing Record 16 of Set 2 | skagen
# Processing Record 17 of Set 2 | kot addu
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | saint-joseph
# Processing Record 20 of Set 2 | atar
# Processing Record 21 of Set 2 | meulaboh
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | ixtapa
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 2 | klyuchi
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | gat
# Processing Record 29 of Set 2 | hvammstangi
# City not found. Skipping...
# Processing Record 30 of Set 2 | hailar
# Processing Record 31 of Set 2 | bela
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | plettenberg bay
# Processing Record 37 of Set 2 | payo
# Processing Record 38 of Set 2 | salalah
# Processing Record 39 of Set 2 | umm kaddadah
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | esperance
# Processing Record 44 of Set 2 | tabuk
# Processing Record 45 of Set 2 | logan
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | grand gaube
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | novikovo
# Processing Record 50 of Set 2 | atagay
# Processing Record 1 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 3 | darhan
# Processing Record 3 of Set 3 | winnemucca
# Processing Record 4 of Set 3 | broome
# Processing Record 5 of Set 3 | north bend
# Processing Record 6 of Set 3 | kafue
# Processing Record 7 of Set 3 | mayo
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | meadow lake
# Processing Record 10 of Set 3 | okhotsk
# Processing Record 11 of Set 3 | walvis bay
# Processing Record 12 of Set 3 | tilichiki
# Processing Record 13 of Set 3 | ilihan
# Processing Record 14 of Set 3 | clyde river
# Processing Record 15 of Set 3 | tuatapere
# Processing Record 16 of Set 3 | strakonice
# Processing Record 17 of Set 3 | vao
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | council bluffs
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | atuona
# Processing Record 22 of Set 3 | tazovskiy
# Processing Record 23 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 3 | chastoozerye
# City not found. Skipping...
# Processing Record 25 of Set 3 | svetlogorsk
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | kyra
# Processing Record 28 of Set 3 | haikou
# Processing Record 29 of Set 3 | kaohsiung
# Processing Record 30 of Set 3 | khatanga
# Processing Record 31 of Set 3 | jiayuguan
# Processing Record 32 of Set 3 | uyuni
# Processing Record 33 of Set 3 | robertsonpet
# Processing Record 34 of Set 3 | nyurba
# Processing Record 35 of Set 3 | hamilton
# Processing Record 36 of Set 3 | sembakung
# Processing Record 37 of Set 3 | kavieng
# Processing Record 38 of Set 3 | isangel
# Processing Record 39 of Set 3 | santander
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | faya
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | bilma
# Processing Record 46 of Set 3 | chapais
# Processing Record 47 of Set 3 | acaponeta
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | zhigansk
# Processing Record 50 of Set 3 | dingle
# Processing Record 1 of Set 4 | tagbac
# Processing Record 2 of Set 4 | arroio grande
# Processing Record 3 of Set 4 | kawalu
# Processing Record 4 of Set 4 | agstafa
# City not found. Skipping...
# Processing Record 5 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 4 | muros
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | kibaek
# Processing Record 9 of Set 4 | narsaq
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | airai
# Processing Record 12 of Set 4 | ostrovnoy
# Processing Record 13 of Set 4 | moree
# Processing Record 14 of Set 4 | kommunisticheskiy
# Processing Record 15 of Set 4 | rotifunk
# Processing Record 16 of Set 4 | tual
# Processing Record 17 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 4 | grindavik
# Processing Record 19 of Set 4 | comodoro rivadavia
# Processing Record 20 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 4 | brae
# Processing Record 22 of Set 4 | bredasdorp
# Processing Record 23 of Set 4 | tiksi
# Processing Record 24 of Set 4 | westport
# Processing Record 25 of Set 4 | mwene-ditu
# Processing Record 26 of Set 4 | chara
# Processing Record 27 of Set 4 | shelburne
# Processing Record 28 of Set 4 | henties bay
# Processing Record 29 of Set 4 | dengfeng
# Processing Record 30 of Set 4 | tasiilaq
# Processing Record 31 of Set 4 | yellowknife
# Processing Record 32 of Set 4 | ornskoldsvik
# Processing Record 33 of Set 4 | honiara
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | llanes
# Processing Record 36 of Set 4 | ghatsila
# Processing Record 37 of Set 4 | saint-francois
# Processing Record 38 of Set 4 | turayf
# Processing Record 39 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 4 | vondrozo
# Processing Record 41 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 4 | tanete
# Processing Record 43 of Set 4 | bathsheba
# Processing Record 44 of Set 4 | bandarbeyla
# Processing Record 45 of Set 4 | kaeo
# Processing Record 46 of Set 4 | naruja
# Processing Record 47 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 4 | port hardy
# Processing Record 49 of Set 4 | bloomingdale
# Processing Record 50 of Set 4 | zlatoust
# Processing Record 1 of Set 5 | chicama
# Processing Record 2 of Set 5 | shimoda
# Processing Record 3 of Set 5 | vila do maio
# Processing Record 4 of Set 5 | la joya
# Processing Record 5 of Set 5 | buraydah
# Processing Record 6 of Set 5 | kahului
# Processing Record 7 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 5 | gimli
# Processing Record 9 of Set 5 | anadyr
# Processing Record 10 of Set 5 | lelydorp
# Processing Record 11 of Set 5 | sagarejo
# Processing Record 12 of Set 5 | tabou
# Processing Record 13 of Set 5 | peterhead
# Processing Record 14 of Set 5 | gondanglegi
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | upington
# Processing Record 17 of Set 5 | creel
# Processing Record 18 of Set 5 | ancud
# Processing Record 19 of Set 5 | dire
# Processing Record 20 of Set 5 | praia da vitoria
# Processing Record 21 of Set 5 | alexandria
# Processing Record 22 of Set 5 | little current
# Processing Record 23 of Set 5 | changde
# Processing Record 24 of Set 5 | yeppoon
# Processing Record 25 of Set 5 | chuy
# Processing Record 26 of Set 5 | broken hill
# Processing Record 27 of Set 5 | genhe
# Processing Record 28 of Set 5 | jacmel
# Processing Record 29 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 5 | talnakh
# Processing Record 31 of Set 5 | bireun
# Processing Record 32 of Set 5 | castro
# Processing Record 33 of Set 5 | paamiut
# Processing Record 34 of Set 5 | lasa
# Processing Record 35 of Set 5 | sisimiut
# Processing Record 36 of Set 5 | itoman
# Processing Record 37 of Set 5 | nuevitas
# Processing Record 38 of Set 5 | port blair
# Processing Record 39 of Set 5 | urumqi
# Processing Record 40 of Set 5 | harur
# Processing Record 41 of Set 5 | kaitangata
# Processing Record 42 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 5 | cockburn town
# Processing Record 44 of Set 5 | ayan
# Processing Record 45 of Set 5 | constitucion
# Processing Record 46 of Set 5 | newport
# Processing Record 47 of Set 5 | arcachon
# Processing Record 48 of Set 5 | severo-kurilsk
# Processing Record 49 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 5 | goderich
# Processing Record 1 of Set 6 | bonavista
# Processing Record 2 of Set 6 | crib point
# Processing Record 3 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 6 | amapa
# Processing Record 5 of Set 6 | vila franca do campo
# Processing Record 6 of Set 6 | pacific grove
# Processing Record 7 of Set 6 | kokkola
# Processing Record 8 of Set 6 | nerchinskiy zavod
# Processing Record 9 of Set 6 | udachnyy
# Processing Record 10 of Set 6 | hualmay
# Processing Record 11 of Set 6 | maceio
# Processing Record 12 of Set 6 | tatawin
# Processing Record 13 of Set 6 | saldanha
# Processing Record 14 of Set 6 | anito
# Processing Record 15 of Set 6 | boo
# Processing Record 16 of Set 6 | joshimath
# Processing Record 17 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 6 | kasongo-lunda
# Processing Record 19 of Set 6 | slavyanka
# Processing Record 20 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 21 of Set 6 | pevek
# Processing Record 22 of Set 6 | rioja
# Processing Record 23 of Set 6 | bexhill
# Processing Record 24 of Set 6 | victoria
# Processing Record 25 of Set 6 | makakilo city
# Processing Record 26 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 6 | caiaponia
# Processing Record 28 of Set 6 | whitefish
# Processing Record 29 of Set 6 | barentu
# Processing Record 30 of Set 6 | sylvan lake
# Processing Record 31 of Set 6 | nakamura
# Processing Record 32 of Set 6 | umba
# Processing Record 33 of Set 6 | morgantown
# Processing Record 34 of Set 6 | tecoanapa
# Processing Record 35 of Set 6 | baykit
# Processing Record 36 of Set 6 | seoul
# Processing Record 37 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 6 | deputatskiy
# Processing Record 39 of Set 6 | jalu
# Processing Record 40 of Set 6 | tessalit
# Processing Record 41 of Set 6 | zvishavane
# Processing Record 42 of Set 6 | kualakapuas
# Processing Record 43 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 44 of Set 6 | kenora
# Processing Record 45 of Set 6 | lavrentiya
# Processing Record 46 of Set 6 | aguimes
# Processing Record 47 of Set 6 | saint-jean-de-luz
# Processing Record 48 of Set 6 | cayenne
# Processing Record 49 of Set 6 | nizhniy kuranakh
# Processing Record 50 of Set 6 | kudahuvadhoo
# Processing Record 1 of Set 7 | sur
# Processing Record 2 of Set 7 | vardo
# Processing Record 3 of Set 7 | maracacume
# Processing Record 4 of Set 7 | presidencia roque saenz pena
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | soe
# Processing Record 7 of Set 7 | terme
# Processing Record 8 of Set 7 | natal
# Processing Record 9 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 10 of Set 7 | coos bay
# Processing Record 11 of Set 7 | manggar
# Processing Record 12 of Set 7 | mercedes
# Processing Record 13 of Set 7 | hofn
# Processing Record 14 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 7 | jiexiu
# Processing Record 16 of Set 7 | asau
# Processing Record 17 of Set 7 | aron
# Processing Record 18 of Set 7 | port augusta
# Processing Record 19 of Set 7 | general roca
# Processing Record 20 of Set 7 | coquimbo
# Processing Record 21 of Set 7 | souillac
# Processing Record 22 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 23 of Set 7 | salinopolis
# Processing Record 24 of Set 7 | amarante do maranhao
# Processing Record 25 of Set 7 | barstow
# Processing Record 26 of Set 7 | sao jose da coroa grande
# Processing Record 27 of Set 7 | kruisfontein
# Processing Record 28 of Set 7 | limon
# Processing Record 29 of Set 7 | mallama
# City not found. Skipping...
# Processing Record 30 of Set 7 | chrzanow
# Processing Record 31 of Set 7 | dmitriyevka
# Processing Record 32 of Set 7 | zyryanka
# Processing Record 33 of Set 7 | puerto quijarro
# Processing Record 34 of Set 7 | valleyview
# Processing Record 35 of Set 7 | syasstroy
# Processing Record 36 of Set 7 | beisfjord
# Processing Record 37 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 7 | asasa
# Processing Record 39 of Set 7 | sao filipe
# Processing Record 40 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 7 | juneau
# Processing Record 42 of Set 7 | ayni
# Processing Record 43 of Set 7 | amahai
# Processing Record 44 of Set 7 | loandjili
# Processing Record 45 of Set 7 | pemangkat
# Processing Record 46 of Set 7 | eydhafushi
# Processing Record 47 of Set 7 | timbiqui
# Processing Record 48 of Set 7 | vrangel
# Processing Record 49 of Set 7 | formosa
# Processing Record 50 of Set 7 | lorengau
# Processing Record 1 of Set 8 | rosarito
# Processing Record 2 of Set 8 | tokoroa
# Processing Record 3 of Set 8 | simpang
# Processing Record 4 of Set 8 | ahuimanu
# Processing Record 5 of Set 8 | berlevag
# Processing Record 6 of Set 8 | muisne
# Processing Record 7 of Set 8 | bengkulu
# Processing Record 8 of Set 8 | picos
# Processing Record 9 of Set 8 | igarka
# Processing Record 10 of Set 8 | cotija
# City not found. Skipping...
# Processing Record 11 of Set 8 | tacarigua
# Processing Record 12 of Set 8 | san jose
# Processing Record 13 of Set 8 | gushikawa
# Processing Record 14 of Set 8 | kuusamo
# Processing Record 15 of Set 8 | male
# Processing Record 16 of Set 8 | verkhnevilyuysk
# Processing Record 17 of Set 8 | vitoria da conquista
# Processing Record 18 of Set 8 | avera
# Processing Record 19 of Set 8 | channel-port aux basques
# Processing Record 20 of Set 8 | birao
# Processing Record 21 of Set 8 | bewar
# Processing Record 22 of Set 8 | lerwick
# Processing Record 23 of Set 8 | vestmannaeyjar
# Processing Record 24 of Set 8 | puerto escondido
# Processing Record 25 of Set 8 | tashigang
# Processing Record 26 of Set 8 | chengkung
# City not found. Skipping...
# Processing Record 27 of Set 8 | sistranda
# Processing Record 28 of Set 8 | markova
# Processing Record 29 of Set 8 | sobolevo
# Processing Record 30 of Set 8 | filingue
# Processing Record 31 of Set 8 | saint-augustin
# Processing Record 32 of Set 8 | tura
# Processing Record 33 of Set 8 | la ronge
# Processing Record 34 of Set 8 | padang
# Processing Record 35 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 36 of Set 8 | ocos
# Processing Record 37 of Set 8 | balasheyka
# Processing Record 38 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 8 | tonekabon
# Processing Record 40 of Set 8 | geraldton
# Processing Record 41 of Set 8 | cabo san lucas
# Processing Record 42 of Set 8 | muzhi
# Processing Record 43 of Set 8 | sarahan
# Processing Record 44 of Set 8 | aquiraz
# Processing Record 45 of Set 8 | cam ranh
# Processing Record 46 of Set 8 | kargasok
# Processing Record 47 of Set 8 | inhambane
# Processing Record 48 of Set 8 | san cristobal
# Processing Record 49 of Set 8 | egvekinot
# Processing Record 50 of Set 8 | axim
# Processing Record 1 of Set 9 | santa isabel do rio negro
# Processing Record 2 of Set 9 | sipe sipe
# Processing Record 3 of Set 9 | svetlyy
# Processing Record 4 of Set 9 | batagay
# Processing Record 5 of Set 9 | leshukonskoye
# Processing Record 6 of Set 9 | belogorsk
# Processing Record 7 of Set 9 | fonte boa
# Processing Record 8 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 9 of Set 9 | porto velho
# Processing Record 10 of Set 9 | komsomolskiy
# Processing Record 11 of Set 9 | deer lake
# Processing Record 12 of Set 9 | collie
# Processing Record 13 of Set 9 | port lincoln
# Processing Record 14 of Set 9 | bolu
# Processing Record 15 of Set 9 | rocha
# Processing Record 16 of Set 9 | provideniya
# Processing Record 17 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 9 | abu dhabi
# Processing Record 19 of Set 9 | cap-aux-meules
# Processing Record 20 of Set 9 | shar
# Processing Record 21 of Set 9 | singaparna
# Processing Record 22 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 9 | taoudenni
# Processing Record 24 of Set 9 | srednekolymsk
# Processing Record 25 of Set 9 | pryozerne
# Processing Record 26 of Set 9 | richards bay
# Processing Record 27 of Set 9 | sundargarh
# Processing Record 28 of Set 9 | coxim
# Processing Record 29 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 30 of Set 9 | uga
# Processing Record 31 of Set 9 | san patricio
# Processing Record 32 of Set 9 | portland
# Processing Record 33 of Set 9 | acapulco
# Processing Record 34 of Set 9 | sangar
# Processing Record 35 of Set 9 | balkhash
# Processing Record 36 of Set 9 | chegdomyn
# Processing Record 37 of Set 9 | puerto del rosario
# Processing Record 38 of Set 9 | katsuura
# Processing Record 39 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 40 of Set 9 | sohag
# Processing Record 41 of Set 9 | homer
# Processing Record 42 of Set 9 | tanabe
# Processing Record 43 of Set 9 | velikiy novgorod
# Processing Record 44 of Set 9 | oktyabrskiy
# Processing Record 45 of Set 9 | bonthe
# Processing Record 46 of Set 9 | rumoi
# Processing Record 47 of Set 9 | porto novo
# Processing Record 48 of Set 9 | peniche
# Processing Record 49 of Set 9 | sept-iles
# Processing Record 50 of Set 9 | faanui
# Processing Record 1 of Set 10 | lazaro cardenas
# Processing Record 2 of Set 10 | port moresby
# Processing Record 3 of Set 10 | ilulissat
# Processing Record 4 of Set 10 | hobyo
# Processing Record 5 of Set 10 | puerto ayacucho
# Processing Record 6 of Set 10 | shingu
# Processing Record 7 of Set 10 | sao joao da barra
# Processing Record 8 of Set 10 | santa marta
# Processing Record 9 of Set 10 | pathein
# Processing Record 10 of Set 10 | porto nacional
# Processing Record 11 of Set 10 | olafsvik
# Processing Record 12 of Set 10 | erzincan
# Processing Record 13 of Set 10 | batagay-alyta
# Processing Record 14 of Set 10 | haverfordwest
# Processing Record 15 of Set 10 | san julian
# Processing Record 16 of Set 10 | arman
# Processing Record 17 of Set 10 | wagar
# Processing Record 18 of Set 10 | rexburg
# Processing Record 19 of Set 10 | acin
# City not found. Skipping...
# Processing Record 20 of Set 10 | matagami
# Processing Record 21 of Set 10 | rivera
# Processing Record 22 of Set 10 | saint anthony
# Processing Record 23 of Set 10 | vostok
# Processing Record 24 of Set 10 | college
# Processing Record 25 of Set 10 | burgeo
# Processing Record 26 of Set 10 | etla
# Processing Record 27 of Set 10 | le plessis-robinson
# Processing Record 28 of Set 10 | biak
# Processing Record 29 of Set 10 | del rio
# Processing Record 30 of Set 10 | olinda
# Processing Record 31 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 10 | umm lajj
# Processing Record 33 of Set 10 | rio claro
# Processing Record 34 of Set 10 | kisii
# Processing Record 35 of Set 10 | kirakira
# Processing Record 36 of Set 10 | ola
# Processing Record 37 of Set 10 | namibe
# Processing Record 38 of Set 10 | delijan
# Processing Record 39 of Set 10 | chumikan
# Processing Record 40 of Set 10 | esna
# Processing Record 41 of Set 10 | moron
# Processing Record 42 of Set 10 | pergamino
# Processing Record 43 of Set 10 | kloulklubed
# Processing Record 44 of Set 10 | les ponts-de-ce
# Processing Record 45 of Set 10 | invermere
# Processing Record 46 of Set 10 | mackay
# Processing Record 47 of Set 10 | khromtau
# Processing Record 48 of Set 10 | xiongzhou
# Processing Record 49 of Set 10 | mwingi
# Processing Record 50 of Set 10 | kununurra
# Processing Record 1 of Set 11 | labuhan
# Processing Record 2 of Set 11 | huarmey
# Processing Record 3 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 11 | arkhangelsk
# Processing Record 5 of Set 11 | sirathu
# Processing Record 6 of Set 11 | vedaranniyam
# City not found. Skipping...
# Processing Record 7 of Set 11 | bubaque
# Processing Record 8 of Set 11 | curitibanos
# Processing Record 9 of Set 11 | ambovombe
# Processing Record 10 of Set 11 | palu
# Processing Record 11 of Set 11 | urambo
# Processing Record 12 of Set 11 | rosario
# Processing Record 13 of Set 11 | havre-saint-pierre
# Processing Record 14 of Set 11 | kamenka
# Processing Record 15 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 16 of Set 11 | lahaina
# Processing Record 17 of Set 11 | mehamn
# Processing Record 18 of Set 11 | nizhniy odes
# Processing Record 19 of Set 11 | camana
# Processing Record 20 of Set 11 | takoradi
# Processing Record 21 of Set 11 | boyuibe
# Processing Record 22 of Set 11 | pedreira
# Processing Record 23 of Set 11 | oro valley
# Processing Record 24 of Set 11 | bodesti
# Processing Record 25 of Set 11 | karlstad
# Processing Record 26 of Set 11 | codajas
# Processing Record 27 of Set 11 | ono
# Processing Record 28 of Set 11 | shenjiamen
# Processing Record 29 of Set 11 | palmer
# Processing Record 30 of Set 11 | wajima
# Processing Record 31 of Set 11 | the pas
# Processing Record 32 of Set 11 | north marysville
# City not found. Skipping...
# Processing Record 33 of Set 11 | yulara
# Processing Record 34 of Set 11 | zhongxing
# Processing Record 35 of Set 11 | pangoa
# Processing Record 36 of Set 11 | dalby
# Processing Record 37 of Set 11 | ambulu
# Processing Record 38 of Set 11 | camiri
# Processing Record 39 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 40 of Set 11 | teyateyaneng
# Processing Record 41 of Set 11 | milagres
# Processing Record 42 of Set 11 | khasan
# Processing Record 43 of Set 11 | anaco
# Processing Record 44 of Set 11 | usinsk
# Processing Record 45 of Set 11 | rio gallegos
# Processing Record 46 of Set 11 | mae sai
# Processing Record 47 of Set 11 | tuy hoa
# Processing Record 48 of Set 11 | bumba
# Processing Record 49 of Set 11 | dolinsk
# Processing Record 50 of Set 11 | panacan
# Processing Record 1 of Set 12 | hasaki
# Processing Record 2 of Set 12 | barinitas
# Processing Record 3 of Set 12 | piranhas
# Processing Record 4 of Set 12 | waitati
# Processing Record 5 of Set 12 | vila velha
# Processing Record 6 of Set 12 | hambantota
# Processing Record 7 of Set 12 | bilibino
# Processing Record 8 of Set 12 | husavik
# Processing Record 9 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 10 of Set 12 | kuznechnoye
# Processing Record 11 of Set 12 | zambezi
# Processing Record 12 of Set 12 | yerbogachen
# Processing Record 13 of Set 12 | algiers
# Processing Record 14 of Set 12 | sambava
# Processing Record 15 of Set 12 | pangai
# Processing Record 16 of Set 12 | riyadh
# Processing Record 17 of Set 12 | erenhot
# Processing Record 18 of Set 12 | coihaique
# Processing Record 19 of Set 12 | russell
# Processing Record 20 of Set 12 | warner robins
# Processing Record 21 of Set 12 | razole
# Processing Record 22 of Set 12 | nikki
# Processing Record 23 of Set 12 | sao geraldo do araguaia
# Processing Record 24 of Set 12 | portree
# Processing Record 25 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 12 | havoysund
# Processing Record 27 of Set 12 | grand forks
# Processing Record 28 of Set 12 | yilan
# Processing Record 29 of Set 12 | dhidhdhoo
# Processing Record 30 of Set 12 | araguaina
# Processing Record 31 of Set 12 | avenal
# Processing Record 32 of Set 12 | pingxiang
# Processing Record 33 of Set 12 | biggar
# Processing Record 34 of Set 12 | araouane
# Processing Record 35 of Set 12 | santa rosa
# Processing Record 36 of Set 12 | gangtok
# Processing Record 37 of Set 12 | minervino murge
# Processing Record 38 of Set 12 | rio de jesus
# Processing Record 39 of Set 12 | margate
# Processing Record 40 of Set 12 | voznesenye
# Processing Record 41 of Set 12 | ihosy
# Processing Record 42 of Set 12 | loukhi
# Processing Record 43 of Set 12 | iacu
# Processing Record 44 of Set 12 | puerto rico
# Processing Record 45 of Set 12 | naze
# Processing Record 46 of Set 12 | sile
# Processing Record 47 of Set 12 | athabasca
# Processing Record 48 of Set 12 | kismayo
# Processing Record 49 of Set 12 | tefe
# Processing Record 50 of Set 12 | adamas
# Processing Record 1 of Set 13 | altamont
# Processing Record 2 of Set 13 | tshikapa
# Processing Record 3 of Set 13 | rawson
# Processing Record 4 of Set 13 | kirgiz-miyaki
# Processing Record 5 of Set 13 | chippewa falls
# Processing Record 6 of Set 13 | laguna
# Processing Record 7 of Set 13 | wanning
# Processing Record 8 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 13 | becerril
# Processing Record 10 of Set 13 | nehe
# Processing Record 11 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 13 | kempele
# Processing Record 13 of Set 13 | beringovskiy
# Processing Record 14 of Set 13 | port-cartier
# Processing Record 15 of Set 13 | leningradskiy
# Processing Record 16 of Set 13 | keti bandar
# Processing Record 17 of Set 13 | mayumba
# Processing Record 18 of Set 13 | la rioja
# Processing Record 19 of Set 13 | matay
# Processing Record 20 of Set 13 | xuddur
# Processing Record 21 of Set 13 | gorontalo
# Processing Record 22 of Set 13 | caranavi
# Processing Record 23 of Set 13 | ust-kuyga
# Processing Record 24 of Set 13 | palana
# Processing Record 25 of Set 13 | nalut
# Processing Record 26 of Set 13 | burnie
# Processing Record 27 of Set 13 | mandan
# Processing Record 28 of Set 13 | puro
# Processing Record 29 of Set 13 | santa maria
# Processing Record 30 of Set 13 | ginda
# Processing Record 31 of Set 13 | methoni
# Processing Record 32 of Set 13 | caconda
# Processing Record 33 of Set 13 | morgan city
# Processing Record 34 of Set 13 | jaguaruna
# Processing Record 35 of Set 13 | ndele
# Processing Record 36 of Set 13 | raudeberg
# Processing Record 37 of Set 13 | maldonado
# Processing Record 38 of Set 13 | nanyang
# Processing Record 39 of Set 13 | lamar
# Processing Record 40 of Set 13 | iqaluit
# Processing Record 41 of Set 13 | disna
# Processing Record 42 of Set 13 | cheyenne
# Processing Record 43 of Set 13 | krasnoselkup
# Processing Record 44 of Set 13 | moose factory
# Processing Record 45 of Set 13 | iralaya
# Processing Record 46 of Set 13 | marsh harbour
# Processing Record 47 of Set 13 | jever
# Processing Record 48 of Set 13 | nakusp
# Processing Record 49 of Set 13 | bafoulabe
# Processing Record 50 of Set 13 | bulgan
# Processing Record 1 of Set 14 | wenling
# Processing Record 2 of Set 14 | alvaraes
# Processing Record 3 of Set 14 | ahipara
# Processing Record 4 of Set 14 | dolores
# Processing Record 5 of Set 14 | astana
# Processing Record 6 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 7 of Set 14 | haines junction
# Processing Record 8 of Set 14 | tucuman
# Processing Record 9 of Set 14 | lagoa
# Processing Record 10 of Set 14 | evansville
# Processing Record 11 of Set 14 | yarmouth
# Processing Record 12 of Set 14 | port hawkesbury
# Processing Record 13 of Set 14 | moscow
# Processing Record 14 of Set 14 | ajdabiya
# Processing Record 15 of Set 14 | yenangyaung
# Processing Record 16 of Set 14 | mount gambier
# Processing Record 17 of Set 14 | muhos
# Processing Record 18 of Set 14 | trinidad
# Processing Record 19 of Set 14 | ponnani
# Processing Record 20 of Set 14 | lalmohan
# Processing Record 21 of Set 14 | buta
# Processing Record 22 of Set 14 | high level
# Processing Record 23 of Set 14 | ashikaga
# Processing Record 24 of Set 14 | yumen
# Processing Record 25 of Set 14 | nome
# Processing Record 26 of Set 14 | saint-louis
# Processing Record 27 of Set 14 | sioux lookout
# Processing Record 28 of Set 14 | barras
# Processing Record 29 of Set 14 | orocue
# Processing Record 30 of Set 14 | viedma
# Processing Record 31 of Set 14 | udala
# Processing Record 32 of Set 14 | terekli-mekteb
# Processing Record 33 of Set 14 | acarau
# Processing Record 34 of Set 14 | urucara
# Processing Record 35 of Set 14 | ohara
# Processing Record 36 of Set 14 | hagenow
# Processing Record 37 of Set 14 | san juan del sur
# Processing Record 38 of Set 14 | dire dawa
# Processing Record 39 of Set 14 | zhongshu
# Processing Record 40 of Set 14 | erfurt
# Processing Record 41 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 42 of Set 14 | yar-sale
# Processing Record 43 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 14 | taylorville
# Processing Record 45 of Set 14 | nishihara
# Processing Record 46 of Set 14 | flin flon
# Processing Record 47 of Set 14 | goure
# Processing Record 48 of Set 14 | ugu
# Processing Record 49 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 14 | ponoka
# Processing Record 1 of Set 15 | namatanai
# Processing Record 2 of Set 15 | kattivakkam
# Processing Record 3 of Set 15 | catamarca
# Processing Record 4 of Set 15 | badamdar
# Processing Record 5 of Set 15 | kalmunai
# Processing Record 6 of Set 15 | berea
# Processing Record 7 of Set 15 | mount isa
# Processing Record 8 of Set 15 | taltal
# Processing Record 9 of Set 15 | pietarsaari
# Processing Record 10 of Set 15 | arlit
# Processing Record 11 of Set 15 | gandorhun
# Processing Record 12 of Set 15 | cooma
# Processing Record 13 of Set 15 | bereda
# Processing Record 14 of Set 15 | otaru
# Processing Record 15 of Set 15 | ambon
# Processing Record 16 of Set 15 | daru
# Processing Record 17 of Set 15 | hovd
# Processing Record 18 of Set 15 | luwuk
# Processing Record 19 of Set 15 | byron bay
# Processing Record 20 of Set 15 | dakar
# Processing Record 21 of Set 15 | mayor pablo lagerenza
# Processing Record 22 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 23 of Set 15 | bosconia
# Processing Record 24 of Set 15 | san luis
# Processing Record 25 of Set 15 | sabang
# Processing Record 26 of Set 15 | carandai
# Processing Record 27 of Set 15 | kazachinskoye
# Processing Record 28 of Set 15 | santo antonio do ica
# Processing Record 29 of Set 15 | hay river
# Processing Record 30 of Set 15 | morondava
# Processing Record 31 of Set 15 | chandauli
# Processing Record 32 of Set 15 | naryan-mar
# Processing Record 33 of Set 15 | kuandian
# Processing Record 34 of Set 15 | nouadhibou
# Processing Record 35 of Set 15 | erdenet
# Processing Record 36 of Set 15 | san-pedro
# Processing Record 37 of Set 15 | milkovo
# Processing Record 38 of Set 15 | antalaha
# Processing Record 39 of Set 15 | gobabis
# Processing Record 40 of Set 15 | nizwa
# Processing Record 41 of Set 15 | luganville
# Processing Record 42 of Set 15 | chlorakas
# Processing Record 43 of Set 15 | tiznit
# Processing Record 44 of Set 15 | kurchum
# Processing Record 45 of Set 15 | naerbo
# Processing Record 46 of Set 15 | pindobacu
# Processing Record 47 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 15 | waipawa
# Processing Record 49 of Set 15 | chabahar
# Processing Record 50 of Set 15 | prachuap khiri khan
# Processing Record 1 of Set 16 | pemberton
# Processing Record 2 of Set 16 | caravelas
# Processing Record 3 of Set 16 | alta floresta
# Processing Record 4 of Set 16 | mandurah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  % Humidity  % Cloudiness  \
# 0      Fortuna      US  40.60 -124.16     66.00          77            20
# 1      Rikitea      PF -23.12 -134.97     66.92          72            79
# 2    Mahebourg      MU -20.41   57.70     71.60          73            40
# 3        Bluff      NZ -46.60  168.33     45.00          98           100
# 4      Ushuaia      AR -54.80  -68.30     44.60          77            40
# 5         Pala      TD   9.36   14.90     72.23          95           100
# 6       Albany      US  42.60  -73.97     84.00          43             0
# 7  Fort Nelson      CA  58.81 -122.70     64.40          68            75
# 8  Gornoye Loo      RU  43.71   39.60     69.80          77            40
# 9      Tondela      PT  40.52   -8.08     64.99          79            17
#
#    Wind Speed Current Description
# 0       14.99          few clouds
# 1       18.19       broken clouds
# 2       11.41    scattered clouds
# 3        4.00     overcast clouds
# 4       16.11         shower rain
# 5        1.79          light rain
# 6        8.16           clear sky
# 7        9.17       broken clouds
# 8        8.95    scattered clouds
# 9        1.21          few clouds

# %%
# Create and export the final Data Frame into a CSV
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
